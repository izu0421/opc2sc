# %% [markdown]
# ## Make circle plots

# %%
# %load_ext rpy2.ipython

# %%
# %%R
#
# library(ggplot2)
#
# yy_lengthen_comma <- function(input_df,grouping_col, col_2split){
#   return_df = data.frame()
#   input_df = as.data.frame(input_df)
#   for (row_i in 1:nrow(input_df)){
#     list = strsplit(input_df[row_i,col_2split],split = ",")[[1]]
#     group_name = input_df[row_i,grouping_col]
#     add_df = data.frame(group = rep(group_name,length(list)), list = list)
#     return_df = rbind(return_df, add_df)
#   }
#   return_df
# }
#
# yy_circle_plt =function(df,out_name,grouping){
#   #df = df[order(df$logFC),] <- we can order before, not included in function
#
#   pdf(out_name,width = 5,height = 5)
#   circos.par(start.degree = 90)
#   chordDiagram(df,
#                annotationTrack = c("grid"), big.gap = 10,directional = 1,
#                grid.col = grouping,
#                link.sort = TRUE)
#
#   circos.trackPlotRegion(track.index = 1, panel.fun = function(x, y) {
#     xlim = get.cell.meta.data("xlim")
#     ylim = get.cell.meta.data("ylim")
#     sector.name = get.cell.meta.data("sector.index")
#     circos.text(mean(xlim), ylim[1] + 1, sector.name, facing = "clockwise", niceFacing = TRUE, adj = c(0, 0.5))}, bg.border = NA)
#   circos.clear()
#   dev.off()
# }

# %%
# %%R
#
# dt = read.csv("dt_out/1_invivo_analysis/GTEx_Coexpression_PAGA_cellrank_drivers_top200genes_TF_enrichment.tsv", sep = "\t")

# %%
# %%R
# # install.packages("circlize")
# library(circlize)
# Out:
# ========================================
# circlize version 0.4.16
# CRAN page: https://cran.r-project.org/package=circlize
# Github page: https://github.com/jokergoo/circlize
# Documentation: https://jokergoo.github.io/circlize_book/book/
#
# If you use it in published research, please cite:
# Gu, Z. circlize implements and enhances circular visualization
#   in R. Bioinformatics 2014.
#
# This message can be suppressed by:
#   suppressPackageStartupMessages(library(circlize))
# ========================================

# %%
# %%R
# head(dt)
# Out:
#       Query.Name Rank Scaled.Rank Set_name    TF Intersect Set.length
#  gene_set_query    1   0.0006223     EGR2  EGR2        32        300
#  gene_set_query    2   0.0012450      AHR   AHR        30        300
#  gene_set_query    3   0.0018670    FOXD3 FOXD3        29        299
#  gene_set_query    4   0.0024890     GLI1  GLI1        27        299
#  gene_set_query    5   0.0031110    SOX10 SOX10        26        298
#  gene_set_query    6   0.0037340     EBF2  EBF2        26        299
#   FET.p.value      FDR Odds.Ratio            Library
#    6.658e-24 1.07e-20      14.10 GTEx--Coexpression
#    9.284e-22 7.46e-19      13.12 GTEx--Coexpression
#    9.544e-21 5.11e-18      12.68 GTEx--Coexpression
#    1.108e-18 4.45e-16      11.72 GTEx--Coexpression
#    1.045e-17 3.04e-15      11.28 GTEx--Coexpression
#    1.134e-17 3.04e-15      11.24 GTEx--Coexpression
#                                                                                                                                                                                    Overlapping_Genes
#  PROS1,ARHGAP39,AHR,MPZ,PHLDA3,POU3F1,FRMD8,MXRA8,KANK4,DHH,ITPR3,WNT6,EPB41L2,HSPA12A,NES,ITGB4,AATK,TGIF2,SECISBP2L,ITGA6,EGFL8,MATN2,RBMS3,PLEC,AHNAK,SH3TC2,LMNA,ERBB2,CTNNA1,SCN7A,PLEKHA4,VIM
#             IFITM3,PROS1,MPZ,PHLDA3,FRMD8,MXRA8,KANK4,DHH,WNT6,EPB41L2,ADGRG6,S100A10,HSPA12A,ITGB4,AATK,SECISBP2L,RHOA,ITGA6,EGFL8,MATN2,RBMS3,PLEC,AHNAK,LMNA,CTNNA1,SCN7A,LAMB1,PLEKHA4,DLC1,VIM
#              PROS1,ARHGAP39,AHR,OLFML2A,MPZ,PHLDA3,FRMD8,MXRA8,KANK4,DHH,WNT6,EPB41L2,HSPA12A,CUEDC2,ITGB4,AATK,SECISBP2L,SORCS2,ITGA6,EGFL8,MATN2,RBMS3,PLEC,AHNAK,SH3TC2,CTNNA1,SCN7A,PLEKHA4,VIM
#                             PROS1,ARHGAP39,AHR,MPZ,PHLDA3,FRMD8,MXRA8,KANK4,DHH,WNT6,EPB41L2,HSPA12A,CUEDC2,ITGB4,AATK,SECISBP2L,SORCS2,ITGA6,EGFL8,MATN2,RBMS3,PLEC,AHNAK,SH3TC2,SCN7A,PLEKHA4,VIM
#                                   ARHGAP39,AHR,MPZ,PHLDA3,KANK4,DHH,LPAR1,WNT6,EPB41L2,HSPA12A,IGSF11,CUEDC2,ITGB4,AATK,SECISBP2L,SORCS2,ZEB2,ITGA6,PMP2,EGFL8,PLEC,AHNAK,SH3TC2,SCN7A,PLEKHA4,PLP1
#                                             PROS1,AHR,MPZ,PHLDA3,MXRA8,KANK4,DHH,PLAC9,WNT6,EPB41L2,HSPA12A,NES,LAMC1,ITGA7,ITGA6,EGFL8,MATN2,RBMS3,AHNAK,LAMA2,EGFLAM,SCN7A,LAMB1,PLEKHA4,DLC1,VIM

# %%
# %%R
# dt_topX <- head(dt[order(dt$Odds.Ratio, decreasing = TRUE),],5)

# %%
# %%R
#
# # head(dt_top10)
#
# dt_process = yy_lengthen_comma(dt_topX,"TF","Overlapping_Genes")
# head(dt_process)
# Out:
#   group     list
#   EGR2    PROS1
#   EGR2 ARHGAP39
#   EGR2      AHR
#   EGR2      MPZ
#   EGR2   PHLDA3
#   EGR2   POU3F1

# %% [markdown]
# Only keep duplicated - dont run

# %%
# %%R
# # list_counts <- table(dt_process$list)
#
# # # Filter rows where "list" items are repeated more than 2 times
# # dt_duplicated <- dt_process[dt_process$list %in% names(list_counts[list_counts > 2]), ]
#
# # # View the number of rows in the filtered dataset
# # nrow(dt_duplicated)
# Out:
# NULL

# %%
# %%R
# dt_duplicated = dt_process

# %% [markdown]
# For some reason, I had to add a -1 for the colors.

# %%
# %%R
# ## this is just for saving the figure
# pdf("figures/chord_plot_TFenrichment_top5_top200genes_invivo_CHEA3_16Feb2025.pdf",width = 3.5,height = 3.5)
# par(cex = 0.5, mar = c(0, 0, 0, 0))
# circos.par(start.degree = 90)
# chordDiagram(dt_duplicated, annotationTrack = c("grid"), big.gap = 10,
#              grid.col = hcl.colors(length(unique(dt_duplicated$list)) + length(unique(dt_duplicated$group))-1, "ag_Sunset"))
# circos.trackPlotRegion(track.index = 1, panel.fun = function(x, y) {
#   xlim = get.cell.meta.data("xlim")
#   ylim = get.cell.meta.data("ylim")
#   sector.name = get.cell.meta.data("sector.index")
#   circos.text(mean(xlim), ylim[1] + 1, sector.name, facing = "clockwise", niceFacing = TRUE, adj = c(0, 0.5))
# }, bg.border = NA)
#
# circos.clear()

# %%
# %%R
# # pdf("fig/test.pdf",width = 7,height = 7)
# par(cex = 0.5, mar = c(0, 0, 0, 0))
# circos.par(start.degree = 90)
#
# chordDiagram(dt_process, annotationTrack = c("grid"), big.gap = 30,
#              grid.col = hcl.colors(length(unique(dt_process$list)) + length(unique(dt_process$group)) -1, "ag_Sunset"))
# circos.trackPlotRegion(track.index = 1, panel.fun = function(x, y) {
#   xlim = get.cell.meta.data("xlim")
#   ylim = get.cell.meta.data("ylim")
#   sector.name = get.cell.meta.data("sector.index")
#   circos.text(mean(xlim), ylim[1] + 1, sector.name, facing = "clockwise", niceFacing = TRUE, adj = c(0, 0.5))
# }, bg.border = NA)
#
# circos.clear()
